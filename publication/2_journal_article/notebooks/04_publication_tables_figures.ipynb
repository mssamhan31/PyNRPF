# %% [markdown]
# # 04 Publication Tables And Figures
#
# Collect intermediate outputs and prepare publication-facing table files.

# %% [markdown]
# ## Imports And Setup

# %%
from pathlib import Path
import sys

NOTEBOOK_DIR = Path.cwd()
if (NOTEBOOK_DIR / '_experiment_helpers.py').exists():
    sys.path.insert(0, str(NOTEBOOK_DIR))
else:
    sys.path.insert(0, str(NOTEBOOK_DIR / 'publication' / '2_journal_article' / 'notebooks'))

from _experiment_helpers import find_article_root, run_publication_tables

article_root = find_article_root()
print('Article root:', article_root)

# %% [markdown]
# ## Build Table Files
#
# Run this after the earlier notebooks have produced their intermediate and metric CSVs.

# %%
outputs = run_publication_tables(article_root)
for name, path in outputs.items():
    print(name, '->', path)
