# %% [markdown]
# # 04 Publication Tables And Figures
#
# This notebook consolidates the high-signal upstream outputs into a small paper-facing table set and inventories the expected figures.

# %% [markdown]
# ## 1. Imports And Paths
#
# Load config and identify the output folders that will be checked.

# %%
from pathlib import Path
import sys

# Keep notebook imports stable whether the notebook is run from JupyterLab,
# VS Code, or the repository root.
article_root = Path.cwd()
while article_root.name != "2_journal_article":
    if article_root.parent == article_root:
        raise RuntimeError("Could not locate publication/2_journal_article")
    article_root = article_root.parent
notebook_dir = article_root / "notebooks"
if str(notebook_dir) not in sys.path:
    sys.path.insert(0, str(notebook_dir))

import _experiment_helpers as h

cfg = h.load_config(article_root)
paths = h.article_paths(article_root, cfg)
h.ensure_output_dirs(paths)
print(f"Article root: {article_root}")
print(f"Config schema: {cfg['schema_version']}")
print(f"Output root: {paths.outputs}")

print(paths.tables)
print(paths.figures)
# Out:
# Article root: C:\Users\samha\Documents\PyNRPF\publication\2_journal_article
# Config schema: journal_v2
# Output root: C:\Users\samha\Documents\PyNRPF\publication\2_journal_article\outputs
# C:\Users\samha\Documents\PyNRPF\publication\2_journal_article\outputs\tables
# C:\Users\samha\Documents\PyNRPF\publication\2_journal_article\outputs\figures

# %% [markdown]
# ## 2. Consolidate Final Tables
#
# This reads the selected upstream tables, writes four final table CSVs, and exports Markdown/LaTeX versions for manuscript drafting.

# %%
outputs = h.run_publication_tables(article_root)
outputs
# Out:
# {'table01_dataset_summary.csv': WindowsPath('C:/Users/samha/Documents/PyNRPF/publication/2_journal_article/outputs/tables/04_publication_tables_figures/table01_dataset_summary.csv'),
#  'table02_characterisation_summary.csv': WindowsPath('C:/Users/samha/Documents/PyNRPF/publication/2_journal_article/outputs/tables/04_publication_tables_figures/table02_characterisation_summary.csv'),
#  'table03_correction_metrics.csv': WindowsPath('C:/Users/samha/Documents/PyNRPF/publication/2_journal_article/outputs/tables/04_publication_tables_figures/table03_correction_metrics.csv'),
#  'table04_forecast_impact.csv': WindowsPath('C:/Users/samha/Documents/PyNRPF/publication/2_journal_article/outputs/tables/04_publication_tables_figures/table04_forecast_impact.csv')}

# %% [markdown]
# ## 3. Inspect Inventories
#
# These inventories make missing upstream outputs explicit instead of failing silently.

# %%
inventory_dir = paths.intermediate / "04_publication_tables_figures"
table_inventory = __import__("pandas").read_csv(inventory_dir / "01_table_inventory.csv")
figure_inventory = __import__("pandas").read_csv(inventory_dir / "02_figure_inventory.csv")
missing = __import__("pandas").read_csv(inventory_dir / "03_missing_upstream_outputs.csv")
display(table_inventory)
display(figure_inventory)
display(missing)
# Out:
#                                artifact  \
# 0           table01_dataset_summary.csv
# 1  table02_characterisation_summary.csv
# 2        table03_correction_metrics.csv
# 3           table04_forecast_impact.csv
#
#                                                 path  exists  size_bytes
# 0  C:\Users\samha\Documents\PyNRPF\publication\2_...    True         532
# 1  C:\Users\samha\Documents\PyNRPF\publication\2_...    True         164
# 2  C:\Users\samha\Documents\PyNRPF\publication\2_...    True        4920
# 3  C:\Users\samha\Documents\PyNRPF\publication\2_...    True        1734
#                                        artifact  \
# 0          fig01_site_rpf_day_counts_alpha_beta
# 1           fig02_month_hour_heatmap_alpha_beta
# 2  fig03_event_duration_distribution_alpha_beta
# 3                 fig01a_confusion_matrices_day
# 4            fig01b_confusion_matrices_interval
# 5                fig02a_precision_recall_f1_day
# 6           fig02b_precision_recall_f1_interval
# 7    fig01_gamma_series_raw_corrected_reference
# 8                     fig02_gamma_forecast_rmse
# 9                fig03_gamma_forecast_residuals
#
#                                                 path  exists  size_bytes
# 0  C:\Users\samha\Documents\PyNRPF\publication\2_...    True      101471
# 1  C:\Users\samha\Documents\PyNRPF\publication\2_...    True       69591
# 2  C:\Users\samha\Documents\PyNRPF\publication\2_...    True       51560
# 3  C:\Users\samha\Documents\PyNRPF\publication\2_...    True      210208
# 4  C:\Users\samha\Documents\PyNRPF\publication\2_...    True      220068
# 5  C:\Users\samha\Documents\PyNRPF\publication\2_...    True       84678
# 6  C:\Users\samha\Documents\PyNRPF\publication\2_...    True       83888
# 7  C:\Users\samha\Documents\PyNRPF\publication\2_...    True      183864
# 8  C:\Users\samha\Documents\PyNRPF\publication\2_...    True       58390
# 9  C:\Users\samha\Documents\PyNRPF\publication\2_...    True      103999
# Empty DataFrame
# Columns: [artifact, path, exists, size_bytes, kind]
# Index: []
